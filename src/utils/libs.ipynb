# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (7.1.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (8.38.0)
# Requirement already satisfied: psutil>=5.7 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: pyzmq>=25 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: traitlets>=5.4.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: comm>=0.1.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: packaging>=22 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (26.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: stack_data in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: exceptiongroup in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: jedi>=0.16 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: typing_extensions>=4.6 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: decorator in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.5.2)
# Requirement already satisfied: six>=1.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: pure-eval in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.1)

# %%
# !pip list
# Out:
# Package           Version
# ----------------- -----------
# alembic           1.18.3
# asttokens         3.0.1
# colorlog          6.10.1
# comm              0.2.3
# debugpy           1.8.20
# decorator         5.2.1
# exceptiongroup    1.3.1
# executing         2.2.1
# greenlet          3.3.1
# imbalanced-learn  0.14.1
# imblearn          0.0
# ipykernel         7.1.0
# ipython           8.38.0
# jedi              0.19.2
# joblib            1.5.3
# jupyter_client    8.8.0
# jupyter_core      5.9.1
# Mako              1.3.10
# MarkupSafe        3.0.3
# matplotlib-inline 0.2.1
# nest-asyncio      1.6.0
# numpy             2.2.6
# optuna            4.7.0
# packaging         26.0
# pandas            2.3.3
# parso             0.8.5
# pexpect           4.9.0
# pip               22.0.2
# platformdirs      4.5.1
# prompt_toolkit    3.0.52
# psutil            7.2.2
# ptyprocess        0.7.0
# pure_eval         0.2.3
# Pygments          2.19.2
# python-dateutil   2.9.0.post0
# pytz              2025.2
# PyYAML            6.0.3
# pyzmq             27.1.0
# scikit-learn      1.7.2
# scipy             1.15.3
# setuptools        59.6.0
# six               1.17.0
# sklearn-compat    0.1.5
# SQLAlchemy        2.0.46
# stack-data        0.6.3
# threadpoolctl     3.6.0
# tomli             2.4.0
# tornado           6.5.4
# tqdm              4.67.1
# traitlets         5.14.3
# typing_extensions 4.15.0
# tzdata            2025.3
# wcwidth           0.5.2

# %%
# !pip install basedosdados
# Out:
# Collecting basedosdados
#   Downloading basedosdados-2.0.2-py3-none-any.whl (38 kB)
# Collecting google-cloud-bigquery-connection<2.0,>=1.12
#   Downloading google_cloud_bigquery_connection-1.20.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 KB 2.2 MB/s eta 0:00:00
# Collecting loguru<0.8.0,>=0.7.0
#   Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 KB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5,>=4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from basedosdados) (4.67.1)
# Collecting google-api-python-client<3.0,>=2.86
#   Downloading google_api_python_client-2.188.0-py3-none-any.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 11.3 MB/s eta 0:00:0000:0100:01
# Collecting pandas-gbq>=0.19
#   Downloading pandas_gbq-0.33.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 KB 15.3 MB/s eta 0:00:00
# Collecting google-cloud-bigquery-storage<3.0,>=2.19
#   Downloading google_cloud_bigquery_storage-2.36.0-py3-none-any.whl (303 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.7/303.7 KB 11.4 MB/s eta 0:00:00
# Collecting google-cloud-storage<3.0,>=2.9
#   Downloading google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 KB 12.4 MB/s eta 0:00:00
# Collecting tomlkit<0.12,>=0.11
#   Downloading tomlkit-0.11.8-py3-none-any.whl (35 kB)
# Collecting google-cloud-bigquery<4.0,>=3.10
#   Downloading google_cloud_bigquery-3.40.0-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 KB 11.1 MB/s eta 0:00:00
# Collecting pydata-google-auth<2.0,>=1.8
#   Downloading pydata_google_auth-1.9.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas<3.0,>=2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from basedosdados) (2.3.3)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.3.0-py3-none-any.whl (9.5 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5
#   Downloading google_api_core-2.29.0-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.9/173.9 KB 10.6 MB/s eta 0:00:00
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0
#   Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.5/236.5 KB 12.0 MB/s eta 0:00:00
# Collecting httplib2<1.0.0,>=0.19.0
#   Downloading httplib2-0.31.2-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 KB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.9.0.post0)
# Requirement already satisfied: packaging>=24.2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (26.0)
# Collecting google-resumable-media<3.0.0,>=2.0.0
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 KB 12.1 MB/s eta 0:00:00
# Collecting google-cloud-core<3.0.0,>=2.4.1
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Collecting requests<3.0.0,>=2.21.0
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 KB 10.3 MB/s eta 0:00:00
# Collecting proto-plus<2.0.0,>=1.22.3
#   Downloading proto_plus-1.27.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 13.6 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2
#   Downloading protobuf-6.33.5-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.5/323.5 KB 11.3 MB/s eta 0:00:00
# Collecting grpc-google-iam-v1<1.0.0,>=0.14.0
#   Downloading grpc_google_iam_v1-0.14.3-py3-none-any.whl (32 kB)
# Collecting grpcio<2.0.0,>=1.33.2
#   Downloading grpcio-1.76.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 11.5 MB/s eta 0:00:0000:0100:01
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Requirement already satisfied: tzdata>=2022.7 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pandas<3.0,>=2.0->basedosdados) (2025.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pandas<3.0,>=2.0->basedosdados) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pandas<3.0,>=2.0->basedosdados) (2025.2)
# Collecting pyarrow>=4.0.0
#   Downloading pyarrow-23.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 MB 10.6 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib>=0.7.0
#   Downloading google_auth_oauthlib-1.2.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: psutil>=5.9.8 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pandas-gbq>=0.19->basedosdados) (7.2.2)
# Requirement already satisfied: setuptools in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pandas-gbq>=0.19->basedosdados) (59.6.0)
# Collecting db-dtypes<2.0.0,>=1.0.4
#   Downloading db_dtypes-1.5.0-py3-none-any.whl (18 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.5/297.5 KB 12.2 MB/s eta 0:00:00
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 13.4 MB/s eta 0:00:00
# Collecting cryptography>=38.0.3
#   Downloading cryptography-46.0.4-cp38-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 11.5 MB/s eta 0:00:0000:0100:01
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.33.2->google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (4.15.0)
# Collecting pyparsing<4,>=3.1
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 KB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.17.0)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 KB 11.5 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 KB 9.1 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 KB 13.2 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.6/153.6 KB 11.0 MB/s eta 0:00:00
# Collecting cffi>=2.0.0
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 KB 11.3 MB/s eta 0:00:00
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 KB 11.6 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 KB 11.3 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 KB 8.7 MB/s eta 0:00:00
# Installing collected packages: urllib3, uritemplate, tomlkit, pyparsing, pycparser, pyasn1, pyarrow, protobuf, oauthlib, loguru, idna, grpcio, google-crc32c, charset_normalizer, certifi, rsa, requests, pyasn1-modules, proto-plus, httplib2, googleapis-common-protos, google-resumable-media, cffi, requests-oauthlib, grpcio-status, db-dtypes, cryptography, grpc-google-iam-v1, google-auth, google-auth-oauthlib, google-auth-httplib2, google-api-core, pydata-google-auth, google-cloud-core, google-api-python-client, google-cloud-storage, google-cloud-bigquery-storage, google-cloud-bigquery-connection, google-cloud-bigquery, pandas-gbq, basedosdados
# Successfully installed basedosdados-2.0.2 certifi-2026.1.4 cffi-2.0.0 charset_normalizer-3.4.4 cryptography-46.0.4 db-dtypes-1.5.0 google-api-core-2.29.0 google-api-python-client-2.188.0 google-auth-2.48.0 google-auth-httplib2-0.3.0 google-auth-oauthlib-1.2.4 google-cloud-bigquery-3.40.0 google-cloud-bigquery-connection-1.20.0 google-cloud-bigquery-storage-2.36.0 google-cloud-core-2.5.0 google-cloud-storage-2.19.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 grpc-google-iam-v1-0.14.3 grpcio-1.76.0 grpcio-status-1.76.0 httplib2-0.31.2 idna-3.11 loguru-0.7.3 oauthlib-3.3.1 pandas-gbq-0.33.0 proto-plus-1.27.0 protobuf-6.33.5 pyarrow-23.0.0 pyasn1-0.6.2 pyasn1-modules-0.4.2 pycparser-3.0 pydata-google-auth-1.9.1 pyparsing-3.3.2 requests-2.32.5 requests-oauthlib-2.0.0 rsa-4.9.1 tomlkit-0.11.8 uritemplate-4.2.0 urllib3-2.6.3

# %%
# !pip list

# %%
# !pip install --upgrade ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 KB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipython>=6.1.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipywidgets) (8.38.0)
# Requirement already satisfied: comm>=0.1.3 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 KB 9.8 MB/s eta 0:00:00a 0:00:01
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.4 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: pexpect>4.3 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: exceptiongroup in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: stack_data in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: decorator in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: typing_extensions>=4.6 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.5.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15

# %%
# !pip install --upgrade jupyterlab notebook
# Out:
# Collecting jupyterlab
#   Downloading jupyterlab-4.5.3-py3-none-any.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 895.9 kB/s eta 0:00:0000:0100:01
# Collecting notebook
#   Downloading notebook-7.5.3-py3-none-any.whl (14.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 955.5 kB/s eta 0:00:0000:0100:01
# Collecting jinja2>=3.0.3
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 612.1 kB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-server<3,>=2.28.0
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 KB 535.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools>=41.1.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (59.6.0)
# Requirement already satisfied: packaging in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (26.0)
# Requirement already satisfied: tornado>=6.2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (6.5.4)
# Requirement already satisfied: jupyter-core in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (5.9.1)
# Requirement already satisfied: traitlets in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (7.1.0)
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 KB 694.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tomli>=1.2.2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab) (2.4.0)
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Collecting httpx<1,>=0.25.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 708.2 kB/s eta 0:00:0000:0100:01
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.1.0-py3-none-any.whl (6.9 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.17.0-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.2/388.2 KB 667.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing_extensions>=4.0.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab) (4.15.0)
# Requirement already satisfied: certifi in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.1.4)
# Requirement already satisfied: idna in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Collecting anyio
#   Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 KB 922.0 kB/s eta 0:00:00a 0:00:01
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pyzmq>=25 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (27.1.0)
# Requirement already satisfied: psutil>=5.7 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.2.2)
# Requirement already satisfied: comm>=0.1.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.20)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (8.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (8.38.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyter-core->jupyterlab) (4.5.1)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting send2trash>=1.8.2
#   Downloading send2trash-2.1.0-py3-none-any.whl (17 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.4-py3-none-any.whl (13 kB)
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.17.0-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 KB 765.9 kB/s eta 0:00:00a 0:00:01
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 KB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.24.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 KB 869.7 kB/s eta 0:00:00 0:00:01
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.26.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 KB 730.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.31 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.32.5)
# Collecting json5>=0.9.0
#   Downloading json5-0.13.0-py3-none-any.whl (36 kB)
# Collecting babel>=2.10
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 1.1 MB/s eta 0:00:0000:010:010m
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 KB 409.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: stack_data in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: decorator in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.52)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.25.0
#   Downloading rpds_py-0.30.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 KB 890.9 kB/s eta 0:00:00a 0:00:01
# Collecting attrs>=22.2.0
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 KB 851.7 kB/s eta 0:00:00a 0:00:01
# Collecting referencing>=0.28.4
#   Downloading referencing-0.37.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyter-client>=8.0.0->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.9.0.post0)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: pyyaml>=5.3 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.3)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-4.0.0-py3-none-any.whl (15 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.4-py3-none-any.whl (25 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 KB 928.6 kB/s eta 0:00:00a 0:00:01
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.3.0-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 KB 583.4 kB/s eta 0:00:00a 0:00:01
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.2.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 774.0 kB/s eta 0:00:00a 0:00:01
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (2.6.3)
# Requirement already satisfied: ptyprocess in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.5)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Collecting rfc3987-syntax>=1.1.0
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: wcwidth in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.5.2)
# Requirement already satisfied: six>=1.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.17.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.0)
# Collecting soupsieve>=1.6.1
#   Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Requirement already satisfied: pure-eval in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.1)
# Requirement already satisfied: pycparser in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (3.0)
# Collecting lark>=1.2.2
#   Downloading lark-1.3.1-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 KB 987.3 kB/s eta 0:00:0000:0100:01
# Collecting arrow>=0.15.0
#   Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 610.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tzdata in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.3)
# Installing collected packages: webencodings, fastjsonschema, websocket-client, webcolors, uri-template, tinycss2, terminado, soupsieve, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, python-json-logger, prometheus-client, pandocfilters, overrides, mistune, lark, jupyterlab-pygments, jsonpointer, json5, jinja2, h11, fqdn, defusedxml, bleach, babel, attrs, async-lru, rfc3987-syntax, referencing, jupyter-server-terminals, httpcore, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, jsonschema-specifications, isoduration, httpx, argon2-cffi, jsonschema, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
# Successfully installed anyio-4.12.1 argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 async-lru-2.1.0 attrs-25.4.0 babel-2.17.0 beautifulsoup4-4.14.3 bleach-6.3.0 defusedxml-0.7.1 fastjsonschema-2.21.2 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 isoduration-20.11.0 jinja2-3.1.6 json5-0.13.0 jsonpointer-3.0.0 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 jupyter-events-0.12.0 jupyter-lsp-2.3.0 jupyter-server-2.17.0 jupyter-server-terminals-0.5.4 jupyterlab-4.5.3 jupyterlab-pygments-0.3.0 jupyterlab-server-2.28.0 lark-1.3.1 mistune-3.2.0 nbclient-0.10.4 nbconvert-7.17.0 nbformat-5.10.4 notebook-7.5.3 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.24.1 python-json-logger-4.0.0 referencing-0.37.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 rpds-py-0.30.0 send2trash-2.1.0 soupsieve-2.8.3 terminado-0.18.1 tinycss2-1.4.0 uri-template-1.3.0 webcolors-25.10.0 webencodings-0.5.1 websocket-client-1.9.0

# %%
# !pip install -q jupysql sqlalchemy duckdb duckdb-engine

# %%
# !pip install gcloud
# Out:
# Collecting gcloud
#   Downloading gcloud-0.18.3.tar.gz (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.4/454.4 KB 4.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: googleapis-common-protos in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from gcloud) (1.72.0)
# Requirement already satisfied: httplib2>=0.9.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from gcloud) (0.31.2)
# Collecting oauth2client>=2.0.1
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 KB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from gcloud) (6.33.5)
# Requirement already satisfied: six in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from gcloud) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from httplib2>=0.9.1->gcloud) (3.3.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from oauth2client>=2.0.1->gcloud) (0.6.2)
# Requirement already satisfied: rsa>=3.1.4 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from oauth2client>=2.0.1->gcloud) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/gabriel/Documents/UFRGS/SBCAS/.venv/lib/python3.10/site-packages (from oauth2client>=2.0.1->gcloud) (0.4.2)
# Using legacy 'setup.py install' for gcloud, since package 'wheel' is not installed.
# Installing collected packages: oauth2client, gcloud
#   Running setup.py install for gcloud ... done
# Successfully installed gcloud-0.18.3 oauth2client-4.1.3

# %%
# !pip install -q jupysql sqlalchemy sqlalchemy-bigquery google-cloud-bigquery pyarrow db-dtypes

# %%
# %pip install -q pybigquery google-cloud-bigquery
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # NO FIM RODAR

# %%
& "$Env:LOCALAPPDATA\Google\Cloud SDK\google-cloud-sdk\bin\gcloud.cmd" --version
& "$Env:LOCALAPPDATA\Google\Cloud SDK\google-cloud-sdk\bin\gcloud.cmd" auth application-default login
# Out:
#   Cell In[1], line 1
#     & "$Env:LOCALAPPDATA\Google\Cloud SDK\google-cloud-sdk\bin\gcloud.cmd" --version
#     ^
# SyntaxError: invalid syntax
